# %%
import pandas as pd

df_legume = pd.read_csv("légumes_data_carrefour.csv")
df_legume
# Out:
#                                        lien du produit  \
# 0    https://www.carrefour.fr/p/avocat-bio-carrefou...
# 1    https://www.carrefour.fr/p/avocat-hass-bio-352...
# 2    https://www.carrefour.fr/p/avocat-hass-bio-352...
# 3    https://www.carrefour.fr/p/asperges-moyennes-v...
# 4    https://www.carrefour.fr/p/asperges-violettes-...
# ..                                                 ...
# 507  https://www.carrefour.fr/p/brocoli-carrefour-3...
# 508  https://www.carrefour.fr/p/brocoli-bio-3270190...
# 509  https://www.carrefour.fr/p/brocoli-bio-3276550...
# 510                                                NaN
# 511                                                NaN
#
#                                     Nom  \
# 0             Avocat Bio CARREFOUR BIO
# 1                      Avocat Hass Bio
# 2                      Avocat Hass Bio
# 3     Asperges moyennes violettes vrac
# 4                   Asperges violettes
# ..                                  ...
# ...

# %%
df_empreinte = pd.read_excel("AGRIBALYSE3.1.1_produits alimentaires - detail etapes.xlsx", sheet_name="Detail etape")

# %%
df_empreinte
# Out:
#      Unnamed: 0   Unnamed: 1  \
# 0           NaN          NaN
# 1      Code AGB  Code CIQUAL
# 2         11084        11084
# 3         11023        11023
# 4         11000        11000
# ...         ...          ...
# 2515       6535         6535
# 2516       6582         6582
# 2517      26146        26146
# 2518      26147        26147
# 2519      25512        25512
#
#      Résultats par étape\nL'arrondi des données peut causer des différences entre la somme des 6 étapes et la Synthèse.\nLa valeur zéro est exprimée "-"  \
# 0                                                   NaN
# 1                                      Groupe d'aliment
# 2                aides culinaires et ingrédients divers
# 3                aides culinaires et ingrédients divers
# 4                aides culinaires et ingrédients divers
# ...                                                 ...
# 2515                            viandes, œufs, poissons
# 2516                            viandes, œufs, poissons
# ...
