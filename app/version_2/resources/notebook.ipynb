# %%
import pandas as pd

df = pd.read_csv('/Users/alexandrecogordan/Documents/ESILV/Ongoing/Introduction to Web Scraping/Projet/app/version_2/resources/vegetables.csv')

df
# Out:
#                                                   link  \
# 0    https://www.carrefour.fr/p/avocat-bio-carrefou...
# 1    https://www.carrefour.fr/p/avocat-hass-bio-352...
# 2    https://www.carrefour.fr/p/avocat-300000103757...
# 3    https://www.carrefour.fr/p/asperges-violette-b...
# 4    https://www.carrefour.fr/p/asperges-verte-bio-...
# ..                                                 ...
# 358  https://www.carrefour.fr/p/ail-oignons-echalot...
# 359  https://www.carrefour.fr/p/oignons-rouges-de-t...
# 360  https://www.carrefour.fr/p/oignon-rouge-carame...
# 361  https://www.carrefour.fr/p/piment-rouge-doux-e...
# 362  https://www.carrefour.fr/p/piment-doux-en-poud...
#
#                                           product_name  \
# 0                                     Avocat Bio  BIO
# 1                                     Avocat Hass Bio
# 2                                              Avocat
# 3                          Asperges violette Bio  BIO
# 4                             Asperges verte Bio  BIO
# ..                                                 ...
# 358   Ail / Oignons / Echalotes : Panier De Condime...
# 359   Oignons Rouges De Tropea Igp Aigre-doux 280 Gr
# 360                  Oignon Rouge Caramélisée 150 Gr
# 361     Piment Rouge Doux En Poudre Deggi Mirch 100g
# 362          Piment Doux En Poudre Quintessence 100g
#
#                                                  image   origin    price  \
# 0    https://media.carrefour.fr/medias/c7d433b8d8b4...  Espagne    1,69
# 1    https://media.carrefour.fr/medias/fbf517249c36...  Espagne    1,69
# 2    https://media.carrefour.fr/medias/5e7a6105d1ec...   Israel    1,19
# 3    https://media.carrefour.fr/medias/fdea62a7ce86...   France    6,99
# 4    https://media.carrefour.fr/medias/12c2e494c77c...   France    6,99
# ..                                                 ...      ...      ...
# 358  https://media.carrefour.fr/medias/61c7c29d4d82...   France   24,95
# 359  https://media.carrefour.fr/medias/35e8fa71fa98...   Italie    5,09
# 360  https://media.carrefour.fr/medias/a5599306fe13...   Italie    5,59
# 361  https://media.carrefour.fr/medias/5ba3cbaca451...    Inde     3,50
# 362  https://media.carrefour.fr/medias/bd071fb10315...  Espagne    4,15
#
#          unit_price vegetable_name  distance                       category  \
# 0       1.69 € / U          Avocat    976.28             Avocat, pulpe, cru
# 1       1.69 € / U          Avocat    976.28             Avocat, pulpe, cru
# 2       1.19 € / U          Avocat   3324.76             Avocat, pulpe, cru
# 3     13.98 € / KG        Asperges      0.00  Asperge, appertisée, égouttée
# 4     17.48 € / KG        Asperges      0.00  Asperge, appertisée, égouttée
# ..              ...            ...       ...                            ...
# 358    8.32 € / kg             Ail      0.00                    Oignon, cru
# 359             NaN        Oignons    961.61                    Oignon, cru
# 360             NaN         Oignon    961.61                    Oignon, cru
# 361             NaN         Piment       NaN                    Piment, cru
# 362             NaN         Piment    976.28                    Piment, cru
#
#      agriculture  transformation  packaging  transport  distribution  \
# 0       0.861392        0.000000   0.000000   0.463698      0.017811
# 1       0.861392        0.000000   0.000000   0.463698      0.017811
# 2       0.861392        0.000000   0.000000   0.463698      0.017811
# 3       0.532289        0.203049   0.171828   0.230945      0.015812
# 4       0.532289        0.203049   0.171828   0.230945      0.015812
# ..           ...             ...        ...        ...           ...
# 358     0.100028        0.000000   0.000000   0.246355      0.011013
# 359     0.100028        0.000000   0.000000   0.246355      0.011013
# 360     0.100028        0.000000   0.000000   0.246355      0.011013
# 361     0.756058        0.000000   0.000000   0.325927      0.021284
# 362     0.756058        0.000000   0.000000   0.325927      0.021284
#
#      consommation  carbon_footprint    bio
# 0        0.137570          1.480470   True
# 1        0.137570          1.480470   True
# 2        0.137570          1.480470  False
# 3        0.000000          1.153923   True
# 4        0.000000          1.153923   True
# ..            ...               ...    ...
# 358      0.032140          0.389536  False
# 359      0.032140          0.389536  False
# 360      0.032140          0.389536  False
# 361      0.080351          1.183620  False
# 362      0.080351          1.183620  False
#
# [363 rows x 17 columns]

# %%
import json

df.to_json('output.json', orient='records')
